# %% [markdown]
# # Analise De Sazonalidade De Queimadas No Para
#
# Agrupamento mensal, correlacao e serie temporal para queimadas em amostra sintetica.
#
# Este notebook registra uma exploração leve sobre amostras seguras e reprodutíveis.

# %%
from pathlib import Path
ROOT = Path.cwd().parents[0]
print("Notebook didático pronto para execução local.")
